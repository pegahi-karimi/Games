# %%
values = {'Ace':11,'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':10,'Queen':10,'King':10}
suits = ['Hearts','Diamonds','Spades','Clubs']
ranks = ['Ace','Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King']

# %%
import random

# %%
class Account():
    
    def __init__(self,balance):
        self.balance = balance
        
    def bet(self,bet_amt):          
        while self.balance < int(bet_amt):
            print('Bet not accepted.')
            bet_amt = input('Enter bet:')
            
        self.bet_amt = int(bet_amt)
        print('Bet accepted!')
        
    def chips(self,num):
        self.num = num
        self.bet_amt += self.num*5
        print(f'\nYour total bet is {self.bet_amt}.\n')
        
    def win(self):
        self.balance += self.bet_amt
        
    def lose(self):
        self.balance -= self.bet_amt
    
    def __str__(self):
        return f'The current balance is {self.balance}'

# %%
class Card():
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
                
    def __str__(self):
        return f'{self.rank} of {self.suit} with a value of {self.value}'

# %%
class Deck():
    
    def __init__(self):   
        self.all_cards = []
        
        for rank in ranks:
            for suit in suits:
                self.all_cards.append(Card(suit,rank))
        
    def shuffle(self):
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        return self.all_cards.pop()

# %%
class Player():
    
    def __init__(self):
        self.hand = []
        
    def hit(self,Deck):
        self.hand.append(Deck.deal_one())

# %%
def Ace_check(a,l):
    if a>21:
        for card in l:
            if card.rank == 'Ace' and a>21:
                l.remove(card)
                a-=10
    return a,l

# %%
player_account = Account(int(input('What is your balance?')))


game_on = True


while game_on:
    
    m = 0
    c = 0
    deck = Deck()

    deck.shuffle()

    player = Player()

    comp = Player()
    
    player_bet = player_account.bet(int(input('How much do you want to bet?')))

    #At the beginning of the game
    
    if len(player.hand) == 0:
        print("\nPlayer's hand is:")
        player.hit(deck)
        print(player.hand[0])
        
        player.hit(deck)
        print(player.hand[1])
        
        comp.hit(deck)
        comp.hit(deck)
    
    resp = 'Y'
    
    #When player wants to continue
    
    while resp == 'Y':

        if m == 0:
            for card in player.hand:
                m+=card.value
            print(f'\nThe total value of cards for player is {m}.')
        
        while m < 21:
            resp = input('Another card? Y or N ').upper()
            if resp == 'Y':
                player_chips = player_account.chips(int(input('How many chips with a value of 5?')))
                
                player.hit(deck)
                print(player.hand[-1])
                m+=player.hand[-1].value
                print(f'\nThe total value of cards for player is {m}.')
            else:
                resp = 'N'
                break
        
        if m == 21:
            break
            
        elif m > 21:
            m,player.hand = Ace_check(m,player.hand)
            print(f'\nThe actual value of cards for player is {m}.\n')
            if m < 21:
                resp = 'Y'
            else:
                resp = 'N'
                
    print(f'Player is equal to {m}.\n')
    
    #Computer's turn if player didn't lose
    
    if m <= 21:
        print("Now it is computer's turn.\n\nComputer's hand is:")

        if c == 0:
            for card in comp.hand:
                c+=card.value
                print(card)

        comp_on = True
        
        while comp_on:
            while c<21 and c<m:
                comp.hit(deck)
                c+=comp.hand[-1].value
                print(comp.hand[-1])

            if c>21:
                c,comp.hand = Ace_check(c,comp.hand)
                if c<21:
                    comp_on = True
                else:
                    comp_on = False
            else:
                comp_on = False
        
        print(f'Comp is equal to {c}.')
        
        if c<=21:
            print('\nYou lost by having lower cards!\n')
            win = False

        else:
            print('\nYou won!\n')
            win = True
            
    else:
        print('You lost by reaching 21!\n')
        win = False        
            
    if win == True:
        player_account.win()
    else:
        player_account.lose()

    print(player_account)
    
    game_on = False
    
    if player_account.balance > 0:
        y = input('Do you want to play again? Y or N ')
        if y.upper() == 'Y':
            game_on = True
# Out:
# What is your balance?88
# How much do you want to bet?8
# Bet accepted!
#
# Player's hand is:
# Ace of Diamonds with a value of 11
# Ace of Spades with a value of 11
#
# The total value of cards for player is 22.
#
# The actual value of cards for player is 12.
# Another card? Y or N y
# How many chips with a value of 5?0
#
# Your total bet is 8.
#
# Four of Hearts with a value of 4
#
# The total value of cards for player is 16.
# Another card? Y or N y
# How many chips with a value of 5?0
#
# Your total bet is 8.
#
# Nine of Diamonds with a value of 9
#
# The total value of cards for player is 25.
#
# The actual value of cards for player is 15.
# Another card? Y or N y
# How many chips with a value of 5?0
#
# Your total bet is 8.
#
# Eight of Hearts with a value of 8
#
# The total value of cards for player is 23.
#
# The actual value of cards for player is 23.
# Player is equal to 23.
#
# You lost by reaching 21!
#
# The current balance is 80
# ...

# %%
print(player_bet)
# Out:
# None
